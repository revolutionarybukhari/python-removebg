# %%
# !pip3 install rembg
# Out:
# ...
#   Using cached rembg-2.0.47-py3-none-any.whl (25 kB)
# ...
#   Using cached onnxruntime-1.15.1-cp311-cp311-win_amd64.whl (6.7 MB)
# ...
#   Using cached pooch-1.7.0-py3-none-any.whl (60 kB)
# ...
#   Using cached PyMatting-1.1.8-py3-none-any.whl (47 kB)
# ...
#   Using cached scikit_image-0.21.0-cp311-cp311-win_amd64.whl (22.8 MB)
# ...
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# ...
#   Using cached numba-0.57.1-cp311-cp311-win_amd64.whl (2.6 MB)
# ...
#   Using cached imageio-2.31.1-py3-none-any.whl (313 kB)
# ...
#   Using cached lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# ...
#   Using cached llvmlite-0.40.1-cp311-cp311-win_amd64.whl (27.7 MB)
# ...
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip3 install Pillow
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Importing Required Modules
import rembg
from PIL import Image
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\onnxruntime\capi\_pybind_state.py:26: UserWarning: Please install the 2019 Visual C++ runtime and then try again. If you've installed the runtime in a non-standard location (other than %SystemRoot%\System32), make sure it can be found by setting the correct path.
#   warnings.warn("Please install the 2019 Visual C++ runtime and then try again. "

# %%
input = Image.open("test.jpg")
input
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1081x630>

# %%
output = rembg.remove(input)
output
# Out:
# <PIL.Image.Image image mode=RGBA size=1081x630>
